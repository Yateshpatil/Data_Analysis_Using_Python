# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\Yatesh\\Desktop\\Python Ca\\1_Practice\\Adult_Income_Dataset\\adult.csv")
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %% [markdown]
# ##  Display top 10 rows of the dataset

# %%
df.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %% [markdown]
# ## Display last 10 rows of the dataset

# %%
df.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %% [markdown]
# ## Shape of the DataSet

# %%
print("No of rows", df.shape[0])
print("No of Columns", df.shape[1])
# Out:
# No of rows 48842
# No of Columns 15

# %% [markdown]
# ## Getting Information About Our Dataset Like Total Number Rows,Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# ## Fetch Random samples from Dataset (50%)

# %%
df1=df.sample(frac=0.5,random_state=1)
df1
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 391     31           Private  224234       HS-grad                9
# 1899    25           Private  149486       HS-grad                9
# 24506   36  Self-emp-not-inc  343721     Doctorate               16
# 32816   26                 ?  131777     Bachelors               13
# 47892   30         Local-gov   44566     Bachelors               13
# ...    ...               ...     ...           ...              ...
# 31987   56  Self-emp-not-inc   50791       Masters               14
# 8518    38         Local-gov   51240     Bachelors               13
# 1350    18           Private   70021       HS-grad                9
# 23734   31           Private  185528  Some-college               10
# 39491   30         Local-gov  327825       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# ...

# %% [markdown]
# ## Check Null Values In The Dataset

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Performing Data Cleaning,[ Replace '?' with NaN ]

# %%
## first we need to find which columns contains ? and how many

# %%
df.isin(["?"]).sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
import numpy as np

# %%
df=df.replace({"workclass":"?","occupation":"?","native-country":"?"},np.nan) ## or df.replace("?",np.nan)

# %%
df.isin(["?"]).sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Drop all the missing values

# %%
# first we will check how much of the data is missing in percentage

# %%
percentage_missing=df.isnull().sum()*100/len(df)
percentage_missing
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %%
df.dropna(inplace=True) # how="any" is by default hence not mentioned

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.shape
# Out:
# (45222, 15)

# %% [markdown]
# ##  Check For Duplicate Data and Drop Them

# %%
duplicate_rows=df[df.duplicated()]
duplicate_rows
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 864     24           Private  194630     Bachelors               13
# 11189   37           Private   52870     Bachelors               13
# 11212   29           Private   36440     Bachelors               13
# 13848   30           Private  180317     Assoc-voc               11
# 15960   18      Self-emp-inc  378036          12th                8
# 18476   39           Private  184659       HS-grad                9
# 19399   19           Private  130431       5th-6th                3
# 19726   41           Private  116391     Bachelors               13
# 20606   25           Private  308144     Bachelors               13
# 21162   25           Private  308144     Bachelors               13
# 21385   90           Private   52386  Some-college               10
# 24361   21           Private  243368     Preschool                1
# 25452   21           Private  250051  Some-college               10
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (45175, 15)

# %% [markdown]
# ## Get overall statistics

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  45175.000000  4.517500e+04     45175.000000  45175.000000
# mean      38.556170  1.897388e+05        10.119314   1102.576270
# std       13.215349  1.056524e+05         2.551740   7510.249876
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.173925e+05         9.000000      0.000000
# 50%       37.000000  1.783120e+05        10.000000      0.000000
# 75%       47.000000  2.379030e+05        13.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  45175.000000    45175.000000
# mean      88.687593       40.942512
# std      405.156611       12.007730
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %% [markdown]
# ## Drop The Columns education-num, capital-gain, and capital-loss

# %%
df[["educational-num","capital-gain","capital-loss"]]
# Out:
#        educational-num  capital-gain  capital-loss
# 0                    7             0             0
# 1                    9             0             0
# 2                   12             0             0
# 3                   10          7688             0
# 5                    6             0             0
# ...                ...           ...           ...
# 48837               12             0             0
# 48838                9             0             0
# 48839                9             0             0
# 48840                9             0             0
# 48841                9         15024             0
#
# [45175 rows x 3 columns]

# %%
df.drop(columns=["educational-num","capital-gain","capital-loss"],inplace=True)
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %% [markdown]
# # Univariate Analysis

# %%
df["age"].describe()
# Out:
# count    45175.000000
# mean        38.556170
# std         13.215349
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         47.000000
# max         90.000000
# Name: age, dtype: float64

# %% [markdown]
# ### What Is The Distribution of Age Column?

# %%
df["age"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###  Find Total Number of Persons Having Age Between 17 To 48 (Inclusive) Using Between Method

# %%
sum((df["age"]>=17) & (df["age"]<=48))
# Out:
# 34858

# %%
sum(df["age"].between(17,48))
# Out:
# 34858

# %% [markdown]
# ###  What is The Distribution of Workclass Column?

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
df["workclass"].describe()
# Out:
# count       45175
# unique          7
# top       Private
# freq        33262
# Name: workclass, dtype: object

# %%
df["workclass"].value_counts()
# Out:
# Private             33262
# Self-emp-not-inc     3795
# Local-gov            3100
# State-gov            1946
# Self-emp-inc         1645
# Federal-gov          1406
# Without-pay            21
# Name: workclass, dtype: int64

# %%
plt.title("Workclass distribution")
plt.ylabel("count")
plt.xlabel("type of job")

df["workclass"].hist(figsize=(10,10))
# Out:
# <AxesSubplot:title={'center':'Workclass distribution'}, xlabel='type of job', ylabel='count'>

# %% [markdown]
# ### How Many Persons Having Bachelors and Masters Degree?

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
df[(df["education"]=="Bachelors")|(df["education"]=="Masters")]
len(df[(df["education"]=="Bachelors")|(df["education"]=="Masters")])
# Out:
# 10072

# %%
df["education"].isin(["Bachelors","Masters"]).sum()   #another method to calculate people having Bachelor's or masters degree
# Out:
# 10072

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.boxplot(x="income",y="age",data=df)
# Out:
# <AxesSubplot:xlabel='income', ylabel='age'>

# %% [markdown]
# ### Replace income Values With 0 and 1

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
df["income"].value_counts()
# Out:
# <=50K    33973
# >50K     11202
# Name: income, dtype: int64

# %%
sns.countplot("income",data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='income', ylabel='count'>

# %%
def income_data(inc):
    if inc=="<=50K":
        return 0
    else:
        return 1

# %%
df["encoded_salary"]=df["income"].apply(income_data)
df.head(2)
# Out:
#    age workclass  fnlwgt education      marital-status         occupation  \
# 0   25   Private  226802      11th       Never-married  Machine-op-inspct
# 1   38   Private   89814   HS-grad  Married-civ-spouse    Farming-fishing
#
#   relationship   race gender  hours-per-week native-country income  \
# 0    Own-child  Black   Male              40  United-States  <=50K
# 1      Husband  White   Male              50  United-States  <=50K
#
#    encoded_salary
# 0               0
# 1               0

# %%
df.replace({"<=50K":0,">50K":1},inplace=True)

# %%
df["income"].value_counts()
# Out:
# 0    33973
# 1    11202
# Name: income, dtype: int64

# %% [markdown]
# ### Which Workclass Getting The Highest Salary?

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income', 'encoded_salary'],
#       dtype='object')

# %%
df.groupby("workclass")["income"].mean().sort_values(ascending=False)
# Out:
# workclass
# Self-emp-inc        0.554407
# Federal-gov         0.390469
# Local-gov           0.295161
# Self-emp-not-inc    0.279051
# State-gov           0.267215
# Private             0.217816
# Without-pay         0.095238
# Name: income, dtype: float64

# %% [markdown]
# ### who has better chance to get salary more than 50K, Male or Female

# %%
df.groupby("gender")["income"].mean().sort_values(ascending=False)
# Out:
# gender
# Male      0.312609
# Female    0.113692
# Name: income, dtype: float64

# %% [markdown]
# ### Convert workclass Columns Datatype To Category Datatype

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# marital-status    object
# occupation        object
# relationship      object
# race              object
# gender            object
# hours-per-week     int64
# native-country    object
# income             int64
# encoded_salary     int64
# dtype: object

# %%
df["workclass"]=df["workclass"].astype("category")
df.dtypes
# Out:
# age                  int64
# workclass         category
# fnlwgt               int64
# education           object
# marital-status      object
# occupation          object
# relationship        object
# race                object
# gender              object
# hours-per-week       int64
# native-country      object
# income               int64
# encoded_salary       int64
# dtype: object
